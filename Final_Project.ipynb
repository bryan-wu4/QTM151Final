# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

cpr = pd.read_csv("csv_files/cpr.csv")
global_best = pd.read_csv("csv_files/esr_hiy_globalbest.csv")
income_adjusted = pd.read_csv("csv_files/esr_hiy_incomeadjusted.csv")
income_adjusted
# Out:
#      Country_Code   Country  High_Income_Country  Year  HiY_QofL_All_IAScore  \
# 0             ABW     Aruba                    1  1990                   NaN
# 1             ABW     Aruba                    1  1991                   NaN
# 2             ABW     Aruba                    1  1992                   NaN
# 3             ABW     Aruba                    1  1993                   NaN
# 4             ABW     Aruba                    1  1994                   NaN
# ...           ...       ...                  ...   ...                   ...
# 7099          ZWE  Zimbabwe                    0  2017                   NaN
# 7100          ZWE  Zimbabwe                    0  2018                   NaN
# 7101          ZWE  Zimbabwe                    0  2019                   NaN
# 7102          ZWE  Zimbabwe                    0  2020                   NaN
# 7103          ZWE  Zimbabwe                    0  2021                   NaN
#
# ...
